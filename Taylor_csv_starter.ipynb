# %% [markdown]
# This file was used for miscelaneous purposes including looking at and adjusting the original csv data. Examining the datatypes, and pulling the songs and albums to create additional arrays as part of a json data file.

# %%
#import dependencies
import csv
import pandas as pd

#read the csv data
data = pd.read_csv('taylor_swift_spotify.csv')
data.head()
# Out:
#    index                                 name                         album  \
# 0      0              Mine (Taylor's Version)  Speak Now (Taylor's Version)
# 1      1        Sparks Fly (Taylor’s Version)  Speak Now (Taylor's Version)
# 2      2  Back To December (Taylor's Version)  Speak Now (Taylor's Version)
# 3      3         Speak Now (Taylor's Version)  Speak Now (Taylor's Version)
# 4      4         Dear John (Taylor's Version)  Speak Now (Taylor's Version)
#
#   release_date  track_number                      id  \
# 0   2023-07-07             1  7G0gBu6nLdhFDPRLc0HdDG
# 1   2023-07-07             2  3MytWN8L7shNYzGl4tAKRp
# 2   2023-07-07             3  79uDOz0zuuWS7HWxzMmTa2
# 3   2023-07-07             4  5xXqyjLicvEpch72qEryFT
# 4   2023-07-07             5  1zU8j1x3yi9xalMF96pzKp
#
#                                     uri  acousticness  danceability  energy  \
# 0  spotify:track:7G0gBu6nLdhFDPRLc0HdDG       0.00444         0.646   0.783
# ...

# %%
#examining the length of a row
n= len(pd.unique(data['album']))
# Out:
# 25

# %%
#pulling all unique song names from the data. This was copied and added to a json data file
pd.unique(data['name'])
# Out:
# array(["Mine (Taylor's Version)", 'Sparks Fly (Taylor’s Version)',
#        "Back To December (Taylor's Version)",
#        "Speak Now (Taylor's Version)", "Dear John (Taylor's Version)",
#        "Mean (Taylor's Version)", "The Story Of Us (Taylor's Version)",
#        "Never Grow Up (Taylor's Version)", "Enchanted (Taylor's Version)",
#        "Better Than Revenge (Taylor's Version)",
#        "Innocent (Taylor's Version)", "Haunted (Taylor's Version)",
#        "Last Kiss (Taylor's Version)", "Long Live (Taylor's Version)",
#        'Ours (Taylor’s Version)', 'Superman (Taylor’s Version)',
#        'Electric Touch (feat. Fall Out Boy) (Taylor’s Version) (From The Vault)',
#        'When Emma Falls in Love (Taylor’s Version) (From The Vault)',
#        'I Can See You (Taylor’s Version) (From The Vault)',
#        'Castles Crumbling (feat. Hayley Williams) (Taylor’s Version) (From The Vault)',
#        'Foolish One (Taylor’s Version) (From The Vault)',
# ...

# %%
#pulling all unique song names from the data. This was copied and added to a json data file
pd.unique(data['album'])
# Out:
# array(["Speak Now (Taylor's Version)", 'Midnights (The Til Dawn Edition)',
#        'Midnights (3am Edition)', 'Midnights', "Red (Taylor's Version)",
#        "Fearless (Taylor's Version)", 'evermore (deluxe version)',
#        'evermore',
#        'folklore: the long pond studio sessions (from the Disney+ special) [deluxe edition]',
#        'folklore (deluxe version)', 'folklore', 'Lover', 'reputation',
#        'reputation Stadium Tour Surprise Song Playlist',
#        '1989 (Deluxe Edition)', '1989', 'Red (Deluxe Edition)', 'Red',
#        'Speak Now World Tour Live', 'Speak Now (Deluxe Edition)',
#        'Speak Now', 'Fearless Platinum Edition', 'Fearless',
#        'Live From Clear Channel Stripped 2008', 'Taylor Swift'],
#       dtype=object)

# %%
#examinging the data type of each row
data.dtypes
# Out:
# index                 int64
# name                 object
# album                object
# release_date         object
# track_number          int64
# id                   object
# uri                  object
# acousticness        float64
# danceability        float64
# energy              float64
# instrumentalness    float64
# liveness            float64
# loudness            float64
# speechiness         float64
# tempo               float64
# valence             float64
# popularity            int64
# duration_ms           int64
# dtype: object

# %%
#in looking at the data and after adjusting it, an extra column would be created in our new csv file. This line of code dropped that column. 

#data.drop(columns=['Unnamed: 0','index'], inplace =True)

# %%
#adjsuting a clumn to datetime

from datetime import datetime as dt

data['release_date'] =  pd.to_datetime(data['release_date'])

# %%
#exporting the new csv file
data.to_csv('taylor_swift_spotify.csv', index=False)
